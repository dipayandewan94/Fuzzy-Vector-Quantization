# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import skfuzzy as fuzz
import statistics

# %%
import random
x1=[]
for i in range(100):
    b=round(random.uniform(80,100), 3)
    x1.append(b)

y1=[]
for i in range(100):
    b=round(random.uniform(0,20), 3)
    y1.append(b)

z1=[]
for i in range(100):
    b=round(random.uniform(80,100), 3)
    z1.append(b)

x2=[]
for i in range(100):
    b=round(random.uniform(20,50), 3)
    x2.append(b)

y2=[]
for i in range(100):
    b=round(random.uniform(65,80), 3)
    y2.append(b)

z2=[]
for i in range(100):
    b=round(random.uniform(30,55), 3)
    z2.append(b)

x3=[]
for i in range(100):
    b=round(random.uniform(0,25), 3)
    x3.append(b)

y3=[]
for i in range(100):
    b=round(random.uniform(75,100), 3)
    y3.append(b)

z3=[]
for i in range(100):
    b=round(random.uniform(50,70), 3)
    z3.append(b)

# %% [raw]
# import random
# x1=[]
# for i in range(100):
#     b=round(random.uniform(80,100), 3)
#     x1.append(b)
#
# y1=[]
# for i in range(100):
#     b=round(random.uniform(0,20), 3)
#     y1.append(b)
#
# z1=[]
# for i in range(100):
#     b=round(random.uniform(80,100), 3)
#     z1.append(b)
#
# x2=[]
# for i in range(100):
#     b=round(random.uniform(50,80), 3)
#     x2.append(b)
#
# y2=[]
# for i in range(100):
#     b=round(random.uniform(80,100), 3)
#     y2.append(b)
#
# z2=[]
# for i in range(100):
#     b=round(random.uniform(30,55), 3)
#     z2.append(b)
#
# x3=[]
# for i in range(100):
#     b=round(random.uniform(0,20), 3)
#     x3.append(b)
#
# y3=[]
# for i in range(100):
#     b=round(random.uniform(35,55), 3)
#     y3.append(b)
#
# z3=[]
# for i in range(100):
#     b=round(random.uniform(60,75), 3)
#     z3.append(b)

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')

ax.scatter(x1, y1, z1, c='r', s=10, label='vector 1') 
ax.scatter(x2, y2, z2, c='g', s=10, label='vector 2') 
ax.scatter(x3, y3, z3, c='b', s=10, label='vector 3') 

ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
mag1=[]

for i in range(100):
    m1=np.sqrt(x1[i]**2+y1[i]**2+z1[i]**2)
    mag1.append(m1)

mag2=[]

for i in range(100):
    m2=np.sqrt(x2[i]**2+y2[i]**2+z2[i]**2)
    mag2.append(m2)

mag3=[]

for i in range(100):
    m3=np.sqrt(x3[i]**2+y3[i]**2+z3[i]**2)
    mag3.append(m3)

#print(mag1)
#print(mag2)
#print(mag3)

# %%
max1=np.sqrt(100**2+100**2+100**2)
max1
mid1=np.sqrt(50**2+50**2+50**2)
mid1
# Out:
# 86.60254037844386

# %%
s=[]
m=[]
l=[]

V1=np.asarray(mag1)

s1 = fuzz.membership.gaussmf(V1, 0, 60)
m1 = fuzz.membership.gaussmf(V1, mid1, 50)
l1 = fuzz.membership.gaussmf(V1, max1, 60)

V2=np.asarray(mag2)

s2 = fuzz.membership.gaussmf(V2, 0, 60)
m2 = fuzz.membership.gaussmf(V2, mid1, 50)
l2 = fuzz.membership.gaussmf(V2, max1, 60)

V3=np.asarray(mag3)

s3 = fuzz.membership.gaussmf(V3, 0, 60)
m3 = fuzz.membership.gaussmf(V3, mid1, 50)
l3 = fuzz.membership.gaussmf(V3, max1, 60)
print(s1.shape, m1.shape,l1.shape)
print(V1.shape)
# Out:
# (100,) (100,) (100,)
# (100,)

# %%
plt.figure()
plt.plot(np.linspace(min(mag1), max(mag1), num = 100), s1, 'b', linewidth=1.5, label='Cold')
plt.plot(np.linspace(min(mag1), max(mag1), num = 100), m1, 'k', linewidth=1.5, label='Mild')
plt.plot(np.linspace(min(mag1), max(mag1), num = 100), l1, 'm', linewidth=1.5, label='Warm')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
f=[s1[2],m1[2],l1[2]]
f
f=np.asarray(f)
f.shape
# Out:
# (3,)

# %%
f1=[]
V1_fuzzified=[]

for i in range(100):
    V1_fuzzified.append([ ])
    
for i in range(100):
    f1=[s1[i],m1[i],l1[i]]
    #f1=np.asarray(f1)
    V1_fuzzified[i].append(f1)
    
#V1_fuzzified

# %%
f2=[]
V2_fuzzified=[]

for i in range(100):
    V2_fuzzified.append([ ])
    
for i in range(100):
    f2=[s2[i],m2[i],l2[i]]
    #f1=np.asarray(f1)
    V2_fuzzified[i].append(f2)
    
#V2_fuzzified

# %%
f3=[]
V3_fuzzified=[]

for i in range(100):
    V3_fuzzified.append([ ])
    
for i in range(100):
    f3=[s3[i],m3[i],l3[i]]
    #f1=np.asarray(f1)
    V3_fuzzified[i].append(f3)
    
#V3_fuzzified

# %%
V1_fuzzified=np.asarray(V1_fuzzified)
V2_fuzzified=np.asarray(V2_fuzzified)
V3_fuzzified=np.asarray(V3_fuzzified)
V1_fuzzified
# Out:
# array([[[0.07522682, 0.60795534, 0.82921828]],
#
#        [[0.10485019, 0.71653733, 0.74746938]],
#
#        [[0.10796145, 0.72620132, 0.73956234]],
#
#        [[0.09521091, 0.6846801 , 0.77275855]],
#
#        [[0.0988057 , 0.69691241, 0.7631849 ]],
#
#        [[0.08352231, 0.64173049, 0.80510331]],
#
#        [[0.10529415, 0.71793404, 0.74633362]],
#
#        [[0.10676883, 0.7225309 , 0.74257891]],
#
#        [[0.0870824 , 0.65535435, 0.79505152]],
#
#        [[0.09118378, 0.67044985, 0.78369004]],
#
#        [[0.09729391, 0.69182073, 0.76719014]],
#
#        [[0.07505612, 0.60722861, 0.82972473]],
#
#        [[0.11957925, 0.75986495, 0.7110827 ]],
#
#        [[0.14412227, 0.82005058, 0.65587784]],
#
#        [[0.09515365, 0.68448172, 0.77291244]],
#
#        [[0.10266068, 0.70956098, 0.75310748]],
#
#        [[0.06789466, 0.57548864, 0.85133779]],
#
#        [[0.09210984, 0.67377292, 0.78115676]],
#
#        [[0.08277554, 0.63880883, 0.80723435]],
#
# ...

# %%
V1_fuzzified=np.squeeze(V1_fuzzified, axis=1)
V2_fuzzified=np.squeeze(V2_fuzzified, axis=1)
V3_fuzzified=np.squeeze(V3_fuzzified, axis=1)
V1_fuzzified
# Out:
# array([[0.07522682, 0.60795534, 0.82921828],
#        [0.10485019, 0.71653733, 0.74746938],
#        [0.10796145, 0.72620132, 0.73956234],
#        [0.09521091, 0.6846801 , 0.77275855],
#        [0.0988057 , 0.69691241, 0.7631849 ],
#        [0.08352231, 0.64173049, 0.80510331],
#        [0.10529415, 0.71793404, 0.74633362],
#        [0.10676883, 0.7225309 , 0.74257891],
#        [0.0870824 , 0.65535435, 0.79505152],
#        [0.09118378, 0.67044985, 0.78369004],
#        [0.09729391, 0.69182073, 0.76719014],
#        [0.07505612, 0.60722861, 0.82972473],
#        [0.11957925, 0.75986495, 0.7110827 ],
#        [0.14412227, 0.82005058, 0.65587784],
#        [0.09515365, 0.68448172, 0.77291244],
#        [0.10266068, 0.70956098, 0.75310748],
#        [0.06789466, 0.57548864, 0.85133779],
#        [0.09210984, 0.67377292, 0.78115676],
#        [0.08277554, 0.63880883, 0.80723435],
#        [0.06956501, 0.58311745, 0.84623338],
#        [0.1005694 , 0.70275818, 0.75855031],
# ...

# %%
V2_fuzzified.shape
# Out:
# (100, 3)

# %%
V1_fuzzified.shape
# Out:
# (100, 3)

# %%
#V1_fuzzified

# %%
x11=V1_fuzzified[:,0]
y11=V1_fuzzified[:,1]
z11=V1_fuzzified[:,2]

x12=V2_fuzzified[:,0]
y12=V2_fuzzified[:,1]
z12=V2_fuzzified[:,2]

x13=V3_fuzzified[:,0]
y13=V3_fuzzified[:,1]
z13=V3_fuzzified[:,2]
x11
# Out:
# array([0.07522682, 0.10485019, 0.10796145, 0.09521091, 0.0988057 ,
#        0.08352231, 0.10529415, 0.10676883, 0.0870824 , 0.09118378,
#        0.09729391, 0.07505612, 0.11957925, 0.14412227, 0.09515365,
#        0.10266068, 0.06789466, 0.09210984, 0.08277554, 0.06956501,
#        0.1005694 , 0.09114929, 0.13625346, 0.06742714, 0.14073539,
#        0.08592747, 0.13508331, 0.14526964, 0.10993481, 0.13790854,
#        0.10444194, 0.08521956, 0.09746336, 0.11538719, 0.12086054,
#        0.07443792, 0.11901012, 0.15407008, 0.08403342, 0.08199368,
#        0.07751844, 0.09425697, 0.12575725, 0.11600905, 0.14226646,
#        0.07019124, 0.07369631, 0.06380289, 0.10391446, 0.12699485,
#        0.06419678, 0.07073838, 0.08705424, 0.08438702, 0.09719509,
#        0.11723766, 0.10210484, 0.09934256, 0.08638099, 0.1418778 ,
#        0.11883662, 0.08559249, 0.11668541, 0.11331329, 0.07334732,
#        0.0729758 , 0.13238912, 0.106667  , 0.1454692 , 0.10405728,
# ...

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('low membership-->>')
ax.set_ylabel('medium membership-->>')
ax.set_zlabel('high membership-->>')

ax.scatter(x11, y11, z11, c='r', s=10, label='vector 1') 
ax.scatter(x12, y12, z12, c='g', s=10, label='vector 2') 
ax.scatter(x13, y13, z13, c='b', s=10, label='vector 3') 

#ax.axis(xmin=0, xmax=10)
#ax.axis(ymin=0, ymax=10)
#ax.axis(zmin=0, zmax=10)
plt.title('plot after fuzzification')
ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [raw]
# pennies = Decimal( "0.01" )
# dollars = Decimal( "1.00" )
#
# #total= Decimal("123.45") * Decimal("0.075")
# total= Decimal("1.56")
# final= total.quantize( Decimal("1"),rounding= ROUND_HALF_DOWN )
# final

# %% [raw]
# for i in range(1, 15, 2):
#     n = i / 2
#     print(n, "=>", Decimal(str(n)).quantize(Decimal("1"), rounding=ROUND_HALF_UP))

# %% [raw]
# bins=np.linspace(0, 1, num = 11)
# #bins = np.array([0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1])
# inds1 = np.digitize(V1_fuzzified, bins)
# inds2 = np.digitize(V2_fuzzified, bins)
# inds3 = np.digitize(V3_fuzzified, bins)
# V1_fuzz = inds1/10
# V2_fuzz = inds2/10
# V3_fuzz = inds3/10

# %%
def uniform_midtread_quantizer(x, Q):
    '''
    x: input array
    Q: quantization step
    '''
    # limiter
    x = np.copy(x)
    idx = np.where(np.abs(x) >= 1)
    x[idx] = np.ones(x[idx].shape)
    # linear uniform quantization
    xQ = np.round(Q * np.floor(x/Q + 1/2),6)

    return xQ

# %%
step_size = 1/80
V1_fuzz = uniform_midtread_quantizer(V1_fuzzified, step_size)
V2_fuzz = uniform_midtread_quantizer(V2_fuzzified, step_size)
V3_fuzz = uniform_midtread_quantizer(V3_fuzzified, step_size)

# %% [raw]
# bins

# %%
V1_fuzz.shape
# Out:
# (100, 3)

# %%
V1_fuzz
# Out:
# array([[0.075 , 0.6125, 0.825 ],
#        [0.1   , 0.7125, 0.75  ],
#        [0.1125, 0.725 , 0.7375],
#        [0.1   , 0.6875, 0.775 ],
#        [0.1   , 0.7   , 0.7625],
#        [0.0875, 0.6375, 0.8   ],
#        [0.1   , 0.7125, 0.75  ],
#        [0.1125, 0.725 , 0.7375],
#        [0.0875, 0.65  , 0.8   ],
#        [0.0875, 0.675 , 0.7875],
#        [0.1   , 0.6875, 0.7625],
#        [0.075 , 0.6125, 0.825 ],
#        [0.125 , 0.7625, 0.7125],
#        [0.15  , 0.825 , 0.65  ],
#        [0.1   , 0.6875, 0.775 ],
#        [0.1   , 0.7125, 0.75  ],
#        [0.0625, 0.575 , 0.85  ],
#        [0.0875, 0.675 , 0.775 ],
#        [0.0875, 0.6375, 0.8125],
#        [0.075 , 0.5875, 0.85  ],
#        [0.1   , 0.7   , 0.7625],
#        [0.0875, 0.675 , 0.7875],
#        [0.1375, 0.8   , 0.675 ],
#        [0.0625, 0.575 , 0.85  ],
#        [0.1375, 0.8125, 0.6625],
#        [0.0875, 0.65  , 0.8   ],
#        [0.1375, 0.8   , 0.675 ],
#        [0.15  , 0.825 , 0.65  ],
# ...

# %%
x21=V1_fuzz[:,0]
y21=V1_fuzz[:,1]
z21=V1_fuzz[:,2]

x22=V2_fuzz[:,0]
y22=V2_fuzz[:,1]
z22=V2_fuzz[:,2]

x23=V3_fuzz[:,0]
y23=V3_fuzz[:,1]
z23=V3_fuzz[:,2]

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')

ax.scatter(x21, y21, z21, c='r', s=10, label='vector 1') 
ax.scatter(x22, y22, z22, c='g', s=10, label='vector 2') 
ax.scatter(x23, y23, z23, c='b', s=10, label='vector 3') 

ax.legend()
plt.title('Plot after quantization')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
V1_fuzzlist = V1_fuzz.tolist()
V2_fuzzlist = V2_fuzz.tolist()
V3_fuzzlist = V3_fuzz.tolist()

# %%
V1_fuzz.shape
# Out:
# (100, 3)

# %%
max_v1=max(V1_fuzzlist, key=V1_fuzzlist.count)
max_v2=max(V2_fuzzlist, key=V2_fuzzlist.count)
max_v3=max(V3_fuzzlist, key=V3_fuzzlist.count)

#max_v1=np.asarray(max_v1)
print(max_v1,max_v2,max_v3)
# Out:
# [0.1, 0.7125, 0.75] [0.3125, 1.0, 0.4] [0.2125, 0.9375, 0.525]

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('low membership-->>')
ax.set_ylabel('medium membership-->>')
ax.set_zlabel('high membership-->>')

ax.scatter(x11, y11, z11, c='r', s=10, label='vector 1')
ax.scatter(x12, y12, z12, c='g', s=10, label='vector 2')
ax.scatter(x13, y13, z13, c='b', s=10, label='vector 3')

#ax.axis(xmin=0, xmax=10)
#ax.axis(ymin=0, ymax=10)
#ax.axis(zmin=0, zmax=10)
#unit vector
ax.scatter(max_v1[0], max_v1[1], max_v1[2], c='r', s=50, label='vector 1', edgecolors='none') 
ax.scatter(max_v2[0], max_v2[1], max_v2[2], c='g', s=50, label='vector 2', edgecolors='none') 
ax.scatter(max_v3[0], max_v3[1], max_v3[2], c='b', s=50, label='vector 3', edgecolors='none')



ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')



max_v1_mag=np.sqrt(max_v1[0]**2 + max_v1[1]**2 + max_v1[2]**2)
max_v1_xdirect = (max_v1[0]/max_v1_mag)
max_v1_ydirect = (max_v1[1]/max_v1_mag)
max_v1_zdirect = (max_v1[2]/max_v1_mag)


max_v2_mag=np.sqrt(max_v2[0]**2 + max_v2[1]**2 + max_v2[2]**2)
max_v2_xdirect = (max_v2[0]/max_v2_mag)
max_v2_ydirect = (max_v2[1]/max_v2_mag)
max_v2_zdirect = (max_v2[2]/max_v2_mag)


max_v3_mag=np.sqrt(max_v3[0]**2 + max_v3[1]**2 + max_v3[2]**2)
max_v3_xdirect = (max_v3[0]/max_v3_mag)
max_v3_ydirect = (max_v3[1]/max_v3_mag)
max_v3_zdirect = (max_v3[2]/max_v3_mag)


ax.quiver(0, 0, 0, max_v1_xdirect, max_v1_ydirect, max_v1_zdirect, length = 0.8, normalize = True, color='r')
ax.quiver(0, 0, 0, max_v2_xdirect, max_v2_ydirect, max_v2_zdirect, length = 0.8,normalize = True, color='g')
ax.quiver(0, 0, 0, max_v3_xdirect, max_v3_ydirect, max_v3_zdirect, length = 0.98, normalize = True, color='b')

plt.title('Plot with direction vector')
ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')

ax.scatter(x1, y1, z1, c='r', s=10) 
ax.scatter(x2, y2, z2, c='g', s=10) 
ax.scatter(x3, y3, z3, c='b', s=10) 



#unit vector
ax.scatter(max_v1[0], max_v1[1], max_v1[2], c='r', s=50, label='vector 1') 
ax.scatter(max_v2[0], max_v2[1], max_v2[2], c='g', s=50, label='vector 2') 
ax.scatter(max_v3[0], max_v3[1], max_v3[2], c='b', s=50, label='vector 3')



ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')



max_v1_mag=np.sqrt(max_v1[0]**2 + max_v1[1]**2 + max_v1[2]**2)
max_v1_xdirect = (max_v1[0]/max_v1_mag)
max_v1_ydirect = (max_v1[1]/max_v1_mag)
max_v1_zdirect = (max_v1[2]/max_v1_mag)


max_v2_mag=np.sqrt(max_v2[0]**2 + max_v2[1]**2 + max_v2[2]**2)
max_v2_xdirect = (max_v2[0]/max_v2_mag)
max_v2_ydirect = (max_v2[1]/max_v2_mag)
max_v2_zdirect = (max_v2[2]/max_v2_mag)


max_v3_mag=np.sqrt(max_v3[0]**2 + max_v3[1]**2 + max_v3[2]**2)
max_v3_xdirect = (max_v3[0]/max_v3_mag)
max_v3_ydirect = (max_v3[1]/max_v3_mag)
max_v3_zdirect = (max_v3[2]/max_v3_mag)


ax.quiver(0, 0, 0, max_v1_xdirect, max_v1_ydirect, max_v1_zdirect, length = 80, normalize = True, color='r')
ax.quiver(0, 0, 0, max_v2_xdirect, max_v2_ydirect, max_v2_zdirect, length = 80, normalize = True, color='g')
ax.quiver(0, 0, 0, max_v3_xdirect, max_v3_ydirect, max_v3_zdirect, length = 100, normalize = True, color='b')

ax.axis(xmin=0, xmax=100)
ax.axis(ymin=0, ymax=100)
ax.axis(zmin=0, zmax=100)

ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
xnew=round(random.uniform(0,20), 3);
ynew=round(random.uniform(75,100), 3);
znew=round(random.uniform(60,70), 3);
print(xnew,ynew,znew)
# Out:
# 4.17 79.848 62.77

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')

ax.scatter(x1, y1, z1, c='r', s=10) 
ax.scatter(x2, y2, z2, c='g', s=10) 
ax.scatter(x3, y3, z3, c='b', s=10) 
ax.scatter(xnew, ynew, znew, c='k', s=10) 


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
mag_new=np.sqrt(xnew**2+ynew**2+znew**2)
mag_new
# Out:
# 101.65217609082454

# %%
s_new = fuzz.membership.gaussmf(mag_new, 0, 60)
m_new = fuzz.membership.gaussmf(mag_new, mid1, 50)
l_new = fuzz.membership.gaussmf(mag_new, max1, 60)

# %%
V_new_fuzzified=[s_new,m_new,l_new]
V_new_fuzzified
# Out:
# [0.17368073656317548, 0.8765757564125235, 0.5970477788758555]

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('low membership-->>')
ax.set_ylabel('medium membership-->>')
ax.set_zlabel('high membership-->>')

ax.scatter(x11, y11, z11, c='r', s=10) 
ax.scatter(x12, y12, z12, c='g', s=10) 
ax.scatter(x13, y13, z13, c='b', s=10) 
ax.scatter(V_new_fuzzified[0], V_new_fuzzified[1], V_new_fuzzified[2], c='k', s=50) 

#ax.axis(xmin=0, xmax=10)
#ax.axis(ymin=0, ymax=10)
#ax.axis(zmin=0, zmax=10)
plt.title('Plot after fuzzification with new point')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
V_new_fuzz = uniform_midtread_quantizer(V_new_fuzzified, step_size)
V_new_fuzz
# Out:
# array([0.175, 0.875, 0.6  ])

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')

ax.scatter(x21, y21, z21, c='r', s=10, label='vector 1') 
ax.scatter(x22, y22, z22, c='g', s=10, label='vector 2') 
ax.scatter(x23, y23, z23, c='b', s=10, label='vector 3') 
ax.scatter(V_new_fuzz[0], V_new_fuzz[1], V_new_fuzz[2], c='k', s=60, label='new vector') 

ax.legend()
plt.title('Plot after quantization with new point')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
V_new_fuzz_mag=np.sqrt(V_new_fuzz[0]**2 + V_new_fuzz[1]**2 + V_new_fuzz[2]**2)
V_new_fuzz_xdirect = (V_new_fuzz[0]/V_new_fuzz_mag)
V_new_fuzz_ydirect = (V_new_fuzz[1]/V_new_fuzz_mag)
V_new_fuzz_zdirect = (V_new_fuzz[2]/V_new_fuzz_mag)

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('low membership-->>')
ax.set_ylabel('medium membership-->>')
ax.set_zlabel('high membership-->>')

ax.scatter(max_v1[0], max_v1[1], max_v1[2], c='r', s=50, label='vector 1') 
ax.scatter(max_v2[0], max_v2[1], max_v2[2], c='g', s=50, label='vector 2') 
ax.scatter(max_v3[0], max_v3[1], max_v3[2], c='b', s=50, label='vector 3')
ax.scatter(V_new_fuzz[0], V_new_fuzz[1], V_new_fuzz[2], c='k', s=60, label='new vector') 

ax.quiver(0, 0, 0, max_v1_xdirect, max_v1_ydirect, max_v1_zdirect, length = max_v1_mag, normalize = True, color='r')
ax.quiver(0, 0, 0, max_v2_xdirect, max_v2_ydirect, max_v2_zdirect, length = max_v2_mag, normalize = True, color='g')
ax.quiver(0, 0, 0, max_v3_xdirect, max_v3_ydirect, max_v3_zdirect, length = max_v3_mag, normalize = True, color='b')
ax.quiver(0, 0, 0, V_new_fuzz_xdirect, V_new_fuzz_ydirect, V_new_fuzz_zdirect, length = V_new_fuzz_mag, normalize = True, color='k')


ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
V_new_fuzz @ max_v1
# Out:
# 1.0640625

# %%
V_new_fuzz @ max_v2
# Out:
# 1.169375

# %%
V_new_fuzz @ max_v3
# Out:
# 1.1634375000000001

# %%
m_v3=np.asarray(max_v3)
m_v2=np.asarray(max_v2)
m_v1=np.asarray(max_v1)

# %%
def normalize(vector):
    """
    Return the vector, normalized.
    If vector is 2d, treats it as stacked vectors, and normalizes each one.
    """
    if vector.ndim == 1:
        return vector / np.linalg.norm(vector)
    elif vector.ndim == 2:
        return vector / np.linalg.norm(vector, axis=1)[:, np.newaxis]
    else:
        raise_dimension_error(vector)

def magnitude(vector):
    """
    Compute the magnitude of `vector`. For stacked inputs, compute the magnitude
    of each one.
    Args:
        vector (np.arraylike): A `3x1` vector or a `kx3` stack of vectors.
    Returns:
        object: For `3x1` inputs, a `float` with the magnitude. For `kx1`
            inputs, a `kx1` array.
    """
    if vector.ndim == 1:
        return np.linalg.norm(vector)
    elif vector.ndim == 2:
        return np.linalg.norm(vector, axis=1)
    else:
        raise_dimension_error(vector)


# Alias because angle()'s parameter shadows the name.
_normalize = normalize


def angle(v1, v2, look=None, assume_normalized=False, units="deg"):
    """
    Compute the unsigned angle between two vectors. For stacked inputs, the
    angle is computed pairwise.
    When `look` is provided, the angle is computed in that viewing plane
    (`look` is the normal). Otherwise the angle is computed in 3-space.
    Args:
        v1 (np.arraylike): A `3x1` vector or a `kx3` stack of vectors.
        v2 (np.arraylike): A vector or stack of vectors with the same shape as
            `v1`.
        look (np.arraylike): A `3x1` vector specifying the normal of a viewing
            plane, or `None` to compute the angle in 3-space.
        assume_normalized (bool): When `True`, assume the input vectors
            are unit length. This improves performance, however when the inputs
            are not normalized, setting this will cause an incorrect results.
        units (str): `'deg'` to return degrees or `'rad'` to return radians.
    Return:
        object: For `3x1` inputs, a `float` with the angle. For `kx1` inputs,
            a `kx1` array.
    """
    if units not in ["deg", "rad"]:
        raise ValueError("Unrecognized units {}; expected deg or rad".format(units))

    if look is not None:
        # This is a simple approach. Since this is working in two dimensions,
        # a smarter approach could reduce the amount of computation needed.
        v1, v2 = [reject(v, from_v=look) for v in (v1, v2)]

    dot_products = np.einsum("ij,ij->i", v1.reshape(-1, 3), v2.reshape(-1, 3))

    if assume_normalized:
        cosines = dot_products
    else:
        cosines = dot_products / magnitude(v1) / magnitude(v2)

    # Clip, because the dot product can slip past 1 or -1 due to rounding and
    # we can't compute arccos(-1.00001).
    angles = np.arccos(np.clip(cosines, -1.0, 1.0))
    if units == "deg":
        angles = np.degrees(angles)

    return angles[0] if v1.ndim == 1 and v2.ndim == 1 else angles

# %%
angle1 = angle(V_new_fuzz, m_v1,look=None, units="deg")
angle2 = angle(V_new_fuzz, m_v2,look=None, units="deg")
angle3 = angle(V_new_fuzz, m_v3,look=None, units="deg")

# %%
predict={"class1":angle1, "class2":angle2, "class3":angle3}
predict
# Out:
# {'class1': 16.947547968564464,
#  'class2': 12.253886759000201,
#  'class3': 3.54249158907424}

# %%
for key, val in predict.items():
    if val == min(predict.values()):
        print(key)
# Out:
# class3

# %%
dist1 = np.linalg.norm(V_new_fuzz - max_v1)
dist2 = np.linalg.norm(V_new_fuzz - max_v2)
dist3 = np.linalg.norm(V_new_fuzz - max_v3)

# %%
print(dist1,dist2,dist3)
# Out:
# 0.31349840509961135 0.23651109910530627 0.06731456008918126
