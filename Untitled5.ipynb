# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import skfuzzy as fuzz
import statistics

# %%
import random
x1=[]
for i in range(100):
    b=round(random.uniform(0,30), 3)
    x1.append(b)

y1=[]
for i in range(100):
    b=round(random.uniform(0,30), 3)
    y1.append(b)

z1=[]
for i in range(100):
    b=round(random.uniform(0,30), 3)
    z1.append(b)

x2=[]
for i in range(100):
    b=round(random.uniform(40,65), 3)
    x2.append(b)

y2=[]
for i in range(100):
    b=round(random.uniform(40,65), 3)
    y2.append(b)

z2=[]
for i in range(100):
    b=round(random.uniform(40,65), 3)
    z2.append(b)

x3=[]
for i in range(100):
    b=round(random.uniform(75,100), 3)
    x3.append(b)

y3=[]
for i in range(100):
    b=round(random.uniform(75,100), 3)
    y3.append(b)

z3=[]
for i in range(100):
    b=round(random.uniform(75,100), 3)
    z3.append(b)

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')

ax.scatter(x1, y1, z1, c='r', s=10, label='vector 1') 
ax.scatter(x2, y2, z2, c='g', s=10, label='vector 2') 
ax.scatter(x3, y3, z3, c='b', s=10, label='vector 3') 

ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [raw]
# mag1=[]
#
# for i in range(100):
#     m1=np.sqrt(x1[i]**2+y1[i]**2+z1[i]**2)
#     mag1.append(m1)
#
# mag2=[]
#
# for i in range(100):
#     m2=np.sqrt(x2[i]**2+y2[i]**2+z2[i]**2)
#     mag2.append(m2)
#
# mag3=[]
#
# for i in range(100):
#     m3=np.sqrt(x3[i]**2+y3[i]**2+z3[i]**2)
#     mag3.append(m3)
#
# #print(mag1)
# #print(mag2)
# #print(mag3)

# %%
V1=[x1,y1,z1]
V2=[x2,y2,z2]
V3=[x3,y3,z3]

# %%
mag1=np.asarray(mag1)
mag1.shape
# Out:
# (100,)

# %%
s=[]
m=[]
l=[]

#V1=np.asarray(mag1)
V1=np.asarray(V1)

s1 = fuzz.membership.gaussmf(V1, 0, 50)
m1 = fuzz.membership.gaussmf(V1, 50, 50)
l1 = fuzz.membership.gaussmf(V1, 100, 50)

#V2=np.asarray(mag2)
V2=np.asarray(V2)

s2 = fuzz.membership.gaussmf(V2, 0, 50)
m2 = fuzz.membership.gaussmf(V2, 50, 50)
l2 = fuzz.membership.gaussmf(V2, 100, 50)

#V3=np.asarray(mag3)
V3=np.asarray(V3)

s3 = fuzz.membership.gaussmf(V3, 0, 50)
m3 = fuzz.membership.gaussmf(V3, 50, 50)
l3 = fuzz.membership.gaussmf(V3, 100, 50)

# %%
V1[:,45]
# Out:
# array([28.718, 11.219,  0.48 ])

# %%
f=[s1[2],m1[2],l1[2]]
f
f=np.asarray(f)
f.shape
# Out:
# (3, 100)

# %%
i=1
[s1[0,i],m1[0,i],l1[0,i]],[s2[1,i],m2[1,i],l2[1,i]],[s3[2,i],m3[2,i],l3[2,i]]
# Out:
#  [[[0.6774611134481913, 0.9931206468359456, 0.5355810080491658],
#    [0.6462127886776879, 0.9978558667447476, 0.5668466699465898],
#    [0.9738743332183177, 0.7435100433267459, 0.20882201243313145]]],
#  [[[0.4590586543641324, 0.9697496924555319, 0.7536273304928796],
#    [0.6712235331068196, 0.9942833394460555, 0.5418245365814321],
#    [0.9402980427667462, 0.8100345424701899, 0.25671252826813606]]],
#  [[[0.4406261748028167, 0.9614829573263437, 0.7718242277060179],
#    [0.46570908579960596, 0.9724718798781321, 0.7470418142332995],
#    [0.9633212670267334, 0.7679825156302975, 0.22523560029394296]]],
#  [[[0.5587123599869833, 0.9968843636997513, 0.6543450285820969],
#    [0.5227931587007288, 0.9903970227153032, 0.6902307043115425],
#    [0.9987527776291379, 0.6368074147207377, 0.14937012380686]]],
#  [[[0.5688523209106934, 0.9980674497845243, 0.644207486990689],
#    [0.49490330288666584, 0.9828361236106491, 0.7180379305968154],
#    [0.8578698172096009, 0.9052148870622138, 0.3513884686570471]]],
#  [[[0.542472438210545, 0.9943977514509784, 0.6705761572073443],
#    [0.7060435874478184, 0.9863753623359842, 0.5069421903856743],
#    [0.9993267817131882, 0.6287802515049812, 0.14554449304388975]]],
#  [[[0.7107141224239713, 0.9850479013305995, 0.5022561611822823],
#    [0.49246315724135026, 0.9820671139680925, 0.720467026886532],
#    [0.9698121558508789, 0.7534799427868483, 0.2153581376880028]]],
#  [[[0.704676313633505, 0.986751828685456, 0.5083135938160444],
#    [0.6796004797871406, 0.9926966170692639, 0.533439197824044],
#    [0.9975418135009241, 0.6490138559591608, 0.1553396587480082]]]]

# %%
f3=[]
V3_fuzzified=[]

for i in range(100):
    V3_fuzzified.append([ ])
    
for i in range(100):
    #f3=[s3[:,i],m3[:,i],l3[:,i]]
    f3=[[s3[0,i],m3[0,i],l3[0,i]],[s3[1,i],m3[1,i],l3[1,i]],[s3[2,i],m3[2,i],l1[2,i]]]
    #f1=np.asarray(f1)
    V3_fuzzified[i].append(f3)
    
#V3_fuzzified

# %%
V1_fuzzified=np.asarray(V1_fuzzified)
V2_fuzzified=np.asarray(V2_fuzzified)
V3_fuzzified=np.asarray(V3_fuzzified)

# %%
V1_fuzzified=np.squeeze(V1_fuzzified, axis=1)
V2_fuzzified=np.squeeze(V2_fuzzified, axis=1)
V3_fuzzified=np.squeeze(V3_fuzzified, axis=1)

# %%
V2_fuzzified.shape
# Out:
# (100, 3, 3)

# %%
V1_fuzzified
# Out:
# array([[[0.99720191, 0.65184921, 0.15675331],
#         [0.99197297, 0.68310997, 0.17305611],
#         [0.99412685, 0.67209844, 0.16715889]],
#
#        [[0.99347541, 0.675619  , 0.16902545],
#         [0.99017842, 0.69116954, 0.17748483],
#         [0.9932669 , 0.67670769, 0.16960622]],
#
#        [[0.9885595 , 0.69781138, 0.1812086 ],
#         [0.90020797, 0.86364846, 0.30481524],
#         [0.90974121, 0.85245479, 0.29385316]],
#
#        [[0.96530721, 0.76370868, 0.22227746],
#         [0.98386669, 0.71469109, 0.19098796],
#         [0.90436493, 0.85886604, 0.30006315]],
#
#        [[0.84282535, 0.91741484, 0.36736642],
#         [0.92977814, 0.82595971, 0.2699255 ],
#         [0.83680126, 0.92198283, 0.37370496]],
#
#        [[0.94095626, 0.80898199, 0.25586671],
#         [0.95174787, 0.79060633, 0.24160403],
#         [0.92394151, 0.83414627, 0.2770419 ]],
#
#        [[0.95184959, 0.79042204, 0.2414656 ],
#         [0.96683016, 0.76033783, 0.21997257],
#         [0.953869  , 0.78671523, 0.23869972]],
#
#        [[0.99539113, 0.66464679, 0.16326518],
#         [0.97530703, 0.73979441, 0.20643639],
#         [0.86152855, 0.90206646, 0.34746648]],
#
#        [[0.99976284, 0.6197388 , 0.14132725],
#         [0.91966402, 0.83988788, 0.28217527],
#         [0.98120534, 0.72312475, 0.19605236]],
#
#        [[0.92196796, 0.83682124, 0.27941845],
#         [0.99748975, 0.64946041, 0.15556161],
#         [0.94459371, 0.80303227, 0.25114611]],
#
#        [[0.92219081, 0.83652144, 0.2791508 ],
#         [0.99088067, 0.68811372, 0.17579422],
#         [0.87181961, 0.89279995, 0.33634672]],
#
#        [[0.98730052, 0.70264689, 0.18396297],
#         [0.98461746, 0.71218179, 0.18950458],
#         [0.98195859, 0.72080536, 0.19464729]],
#
#        [[0.89182024, 0.87286821, 0.31428637],
#         [0.85465474, 0.90792118, 0.35482247],
#         [0.97017132, 0.7526292 , 0.21479255]],
#
#        [[0.99663547, 0.65621277, 0.15894927],
#         [0.96569609, 0.76285592, 0.22169203],
#         [0.83775934, 0.9212679 , 0.37269891]],
#
#        [[0.95993802, 0.77497341, 0.23016322],
#         [0.95272503, 0.78882645, 0.24027073],
#         [0.94847767, 0.79641328, 0.24601149]],
#
#        [[0.86299318, 0.90078517, 0.34589207],
#         [0.89737633, 0.86682344, 0.30802943],
#         [0.89794362, 0.86619259, 0.30738692]],
#
#        [[0.94412717, 0.80380835, 0.25175613],
#         [0.96234077, 0.77004474, 0.22667757],
#         [0.93185062, 0.82294759, 0.2673644 ]],
#
#        [[0.95127386, 0.7914621 , 0.242248  ],
#         [0.93701175, 0.8151856 , 0.26089964],
#         [0.99263157, 0.67992301, 0.17133138]],
#
#        [[0.99795282, 0.64530689, 0.15350697],
#         [0.99175236, 0.68414743, 0.17362077],
#         [0.85665182, 0.9062467 , 0.35269073]],
#
#        [[0.98039814, 0.72555636, 0.19753559],
#         [0.97922679, 0.72899238, 0.19964949],
#         [0.99814731, 0.64342204, 0.1525818 ]],
#
#        [[0.97916656, 0.72916625, 0.19975703],
#         [0.99563655, 0.6630844 , 0.16245845],
#         [0.97514539, 0.74021936, 0.20670788]],
#
#        [[0.97404884, 0.74306346, 0.20853386],
#         [0.99092889, 0.68789952, 0.17567624],
#         [0.98888413, 0.69652046, 0.18047949]],
#
#        [[0.88035353, 0.88462477, 0.32701419],
#         [0.96329493, 0.76803832, 0.22527449],
#         [0.87241271, 0.89224665, 0.33570158]],
#
#        [[0.89539743, 0.86900395, 0.31026528],
#         [0.94342081, 0.80497598, 0.25267711],
#
#        [[0.99998115, 0.61025471, 0.13700486],
#         [0.98707222, 0.70349672, 0.18445088],
#         [0.85358992, 0.90880531, 0.35595734]],
#
#        [[0.94688079, 0.79916961, 0.24813506],
#         [0.90185339, 0.86177307, 0.30293915],
#         [0.9157315 , 0.84498865, 0.28683961]],
#
#        [[0.99589159, 0.66141297, 0.16159907],
#         [0.99802877, 0.64458204, 0.15315065],
#         [0.9999455 , 0.61286261, 0.13818326]],
#
#        [[0.99382751, 0.67373958, 0.16802683],
#         [0.9820559 , 0.72050203, 0.19446423],
#         [0.99893335, 0.63453222, 0.14827788]],
#
#        [[0.99907764, 0.63257102, 0.14734142],
#         [0.97486898, 0.74094255, 0.2071707 ],
#         [0.99790656, 0.64574174, 0.15372106]],
#
#        [[0.97664565, 0.73621625, 0.20416406],
#         [0.97721134, 0.73467112, 0.20319029],
#         [0.99570888, 0.66261553, 0.162217  ]],
#
#        [[0.99137288, 0.68589924, 0.17457784],
#         [0.88607534, 0.87887439, 0.32069226],
#         [0.99746565, 0.64966556, 0.15566367]],
#
#        [[0.94950944, 0.79460527, 0.24462966],
#         [0.99205337, 0.68272825, 0.17284875],
#         [0.9857743 , 0.70818646, 0.18716441]],
#
#        [[0.95144811, 0.79114808, 0.24201148],
#         [0.99156496, 0.68501756, 0.17409558],
#         [0.85241626, 0.90977287, 0.35720683]],
#
#        [[0.9866582 , 0.70501824, 0.18532734],
#         [0.90839954, 0.85407952, 0.29541002],
#         [0.84507692, 0.91566232, 0.36498916]],
#
#        [[0.993216  , 0.67697082, 0.16974684],
#         [0.99658125, 0.65661029, 0.15915056],
#         [0.99393761, 0.67314075, 0.16770969]],
#
#        [[0.99774999, 0.64717888, 0.15443028],
#         [0.91981451, 0.83968937, 0.28199576],
#         [0.92114848, 0.83791883, 0.28040114]],
#
#        [[0.92933757, 0.82659268, 0.27046753],
#         [0.9932461 , 0.67681534, 0.16966374],
#         [0.95017373, 0.79342962, 0.2437358 ]],
#
#        [[0.91250861, 0.84904952, 0.29062609],
#         [0.99953681, 0.62498771, 0.14376384],
#         [0.94204159, 0.80723064, 0.25446656]],
#
#        [[0.84233219, 0.91779537, 0.3678865 ],
#         [0.86916969, 0.89524586, 0.33922323],
#         [0.97060909, 0.75158462, 0.21410013]],
#
#        [[0.8771636 , 0.88773522, 0.33051549],
#         [0.93430242, 0.81930808, 0.26430935],
#         [0.99599932, 0.66069121, 0.16122914]],
#
#        [[0.9895081 , 0.69398334, 0.17905409],
#         [0.96630081, 0.76151905, 0.22077745],
#         [0.94482312, 0.80264918, 0.25084563]],
#
#        [[0.98470056, 0.7119001 , 0.18933872],
#         [0.91316356, 0.8482327 , 0.28985912],
#         [0.95162807, 0.79082308, 0.24176696]],
#
#        [[0.94923401, 0.79509003, 0.2449993 ],
#         [0.98658695, 0.70527758, 0.18547711],
#         [0.9995819 , 0.6240666 , 0.14333393]],
#
#        [[0.92760629, 0.82905574, 0.27258961],
#         [0.94824296, 0.79682156, 0.24632474],
#         [0.97140053, 0.74967432, 0.21283961]],
#
#        [[0.99940367, 0.62747183, 0.14492825],
#         [0.99885823, 0.63550049, 0.14874194],
#         [0.99899161, 0.63375749, 0.1479074 ]],
#
#        [[0.97555506, 0.73913945, 0.20601863],
#         [0.99873073, 0.63707361, 0.14949833],
#         [0.85808826, 0.90502898, 0.35115473]],
#
#        [[0.99091283, 0.68797092, 0.17571556],
#         [0.98436681, 0.71302651, 0.19000276],
#         [0.93604174, 0.81667406, 0.26212463]],
#
#        [[0.99810821, 0.64380874, 0.15277125],
#         [0.99971396, 0.62103609, 0.14192648],
#         [0.90029876, 0.86354557, 0.30471188]],
#
#        [[0.97532012, 0.73975995, 0.20641439],
#         [0.86849702, 0.89586001, 0.33995191],
#         [0.99758779, 0.64861554, 0.1551419 ]],
#
#        [[0.99588436, 0.66146108, 0.16162376],
#         [0.9918871 , 0.68351547, 0.17327662],
#         [0.95974565, 0.77536067, 0.23043949]],
#
#        [[0.99891015, 0.63483482, 0.14842278],
#         [0.99865306, 0.63799308, 0.14994183],
#         [0.95295605, 0.78840253, 0.23995437]],
#
#        [[0.93320303, 0.82095048, 0.26568271],
#         [0.86693465, 0.89727608, 0.34164207],
#         [0.99620008, 0.65931942, 0.16052796]],
#
#        [[0.99833904, 0.64146392, 0.15162539],
#         [0.91561619, 0.84513576, 0.28697562],
#         [0.97387433, 0.74351004, 0.20882201]],
#
#        [[0.99769338, 0.64768599, 0.15468116],
#         [0.94219124, 0.80698758, 0.25427294],
#         [0.94029804, 0.81003454, 0.25671253]],
#
#        [[0.92457247, 0.83328143, 0.27627906],
#         [0.94870573, 0.7960155 , 0.24570673],
#         [0.96332127, 0.76798252, 0.2252356 ]],
#
#        [[0.84190763, 0.91812202, 0.36833406],
#         [0.98841811, 0.69836773, 0.18152362],
#         [0.99875278, 0.63680741, 0.14937012]],
#
#        [[0.84100779, 0.91881144, 0.36928213],
#         [0.96159068, 0.771602  , 0.22777285],
#         [0.85786982, 0.90521489, 0.35138847]],
#
#        [[0.94942994, 0.79474535, 0.24473641],
#         [0.86385416, 0.90002628, 0.34496534],
#         [0.99932678, 0.62878025, 0.14554449]],
#
#        [[0.91569307, 0.84503769, 0.28688494],
#         [0.9723937 , 0.74723578, 0.21124123],
#         [0.96981216, 0.75347994, 0.21535814]],
#
#        [[0.88129426, 0.88369465, 0.32597855],
#         [0.9995632 , 0.62445445, 0.14351483],
#         [0.99754181, 0.64901386, 0.15533966]]])

# %%
#V1_fuzzified

# %%
x11=V1_fuzzified[:,0]
y11=V1_fuzzified[:,1]
z11=V1_fuzzified[:,2]

x12=V2_fuzzified[:,0]
y12=V2_fuzzified[:,1]
z12=V2_fuzzified[:,2]

x13=V3_fuzzified[:,0]
y13=V3_fuzzified[:,1]
z13=V3_fuzzified[:,2]

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('low membership-->>')
ax.set_ylabel('medium membership-->>')
ax.set_zlabel('high membership-->>')

ax.scatter(x11, y11, z11, c='r', s=10, label='vector 1') 
ax.scatter(x12, y12, z12, c='g', s=10, label='vector 2') 
ax.scatter(x13, y13, z13, c='b', s=10, label='vector 3') 

#ax.axis(xmin=0, xmax=10)
#ax.axis(ymin=0, ymax=10)
#ax.axis(zmin=0, zmax=10)
plt.title('plot after fuzzification')
ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [raw]
# #bins=np.linspace(0, 1, num = 100)
# bins = np.array([0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5])
# inds1 = np.digitize(V1_fuzzified, bins)
# inds2 = np.digitize(V2_fuzzified, bins)
# inds3 = np.digitize(V3_fuzzified, bins)
# V1_fuzz = inds1/10
# V2_fuzz = inds2/10
# V3_fuzz = inds3/10

# %% [raw]
# bins

# %%
def uniform_midtread_quantizer(x, Q):
    '''
    x: input array
    Q: quantization step
    '''
    # limiter
    x = np.copy(x)
    idx = np.where(np.abs(x) >= 1)
    x[idx] = np.ones(x[idx].shape)
    # linear uniform quantization
    xQ = np.round(Q * np.floor(x/Q + 1/2),6)

    return xQ

# %%
step_size = 1/80
V1_fuzz = uniform_midtread_quantizer(V1_fuzzified, step_size)
V2_fuzz = uniform_midtread_quantizer(V2_fuzzified, step_size)
V3_fuzz = uniform_midtread_quantizer(V3_fuzzified, step_size)

# %%
V1_fuzz.shape
# Out:
# (100, 3, 3)

# %%
V1_fuzz
# Out:
# array([[[1.    , 0.65  , 0.1625],
#         [0.9875, 0.6875, 0.175 ],
#         [1.    , 0.675 , 0.1625]],
#
#        [[0.9875, 0.675 , 0.175 ],
#         [0.9875, 0.6875, 0.175 ],
#         [0.9875, 0.675 , 0.175 ]],
#
#        [[0.9875, 0.7   , 0.175 ],
#         [0.9   , 0.8625, 0.3   ],
#         [0.9125, 0.85  , 0.3   ]],
#
#        [[0.9625, 0.7625, 0.225 ],
#         [0.9875, 0.7125, 0.1875],
#         [0.8875, 0.875 , 0.3125]],
#
#        [[0.975 , 0.7375, 0.2   ],
#         [0.95  , 0.7875, 0.2375],
#         [0.9   , 0.8625, 0.3   ]],
#
#        [[0.8875, 0.8875, 0.325 ],
#         [0.9875, 0.725 , 0.2   ],
#         [1.    , 0.675 , 0.1625]],
#
#        [[0.875 , 0.8875, 0.3375],
#         [0.85  , 0.9125, 0.3625],
#         [0.875 , 0.8875, 0.3375]],
#
#        [[0.875 , 0.8875, 0.325 ],
#         [0.975 , 0.75  , 0.2125],
#         [0.9   , 0.8625, 0.3125]],
#
#        [[1.    , 0.625 , 0.15  ],
#         [0.9375, 0.825 , 0.2625],
#         [0.9125, 0.8625, 0.3   ]],
#
#        [[1.    , 0.6125, 0.1375],
#         [1.    , 0.6125, 0.1375],
#         [0.9375, 0.8125, 0.2625]],
#
#        [[0.9375, 0.8125, 0.2625],
#         [1.    , 0.675 , 0.1625],
#         [0.85  , 0.9125, 0.3625]],
#
#        [[0.975 , 0.75  , 0.2125],
#         [0.8625, 0.9   , 0.3375],
#         [0.975 , 0.7375, 0.2   ]],
#
#        [[0.925 , 0.8375, 0.2875],
#         [0.9875, 0.6875, 0.175 ],
#         [1.    , 0.6625, 0.1625]],
#
#        [[0.9625, 0.775 , 0.2375],
#         [0.95  , 0.8   , 0.25  ],
#         [1.    , 0.675 , 0.1625]],
#
#        [[0.9875, 0.675 , 0.1625],
#         [0.95  , 0.7875, 0.2375],
#         [0.9875, 0.6875, 0.175 ]],
#
#        [[0.9875, 0.675 , 0.175 ],
#         [1.    , 0.625 , 0.1375],
#         [0.925 , 0.825 , 0.275 ]],
#
#        [[1.    , 0.6125, 0.1375],
#         [0.8375, 0.925 , 0.375 ],
#         [0.975 , 0.75  , 0.2125]],
#
#        [[1.    , 0.6375, 0.15  ],
#         [0.975 , 0.75  , 0.2125],
#         [0.9375, 0.8125, 0.2625]],
#
#        [[1.    , 0.6625, 0.1625],
#         [0.9875, 0.7   , 0.1875],
#         [0.9875, 0.7   , 0.1875]],
#
#        [[0.9625, 0.775 , 0.2375],
#         [0.9   , 0.8625, 0.3125],
#         [0.9875, 0.6875, 0.175 ]],
#
#        [[1.    , 0.6375, 0.15  ],
#         [0.9   , 0.8625, 0.3   ],
#         [1.    , 0.625 , 0.1375]],
#
#        [[0.9125, 0.85  , 0.2875],
#         [0.9625, 0.7625, 0.225 ],
#         [1.    , 0.625 , 0.15  ]],
#
#        [[0.9625, 0.75  , 0.2125],
#         [0.9375, 0.825 , 0.2625],
#         [0.875 , 0.8875, 0.3375]],
#
#        [[0.95  , 0.7875, 0.2375],
#         [0.9625, 0.7625, 0.225 ],
#         [0.9   , 0.8625, 0.3   ]],
#
#        [[0.8375, 0.9125, 0.3625],
#         [0.925 , 0.825 , 0.275 ],
#         [0.8375, 0.925 , 0.375 ]],
#
#        [[0.9375, 0.8125, 0.25  ],
#         [0.95  , 0.7875, 0.2375],
#         [0.925 , 0.8375, 0.275 ]],
#
#        [[0.95  , 0.7875, 0.2375],
#         [0.9625, 0.7625, 0.225 ],
#         [0.95  , 0.7875, 0.2375]],
#
#        [[1.    , 0.6625, 0.1625],
#         [0.975 , 0.7375, 0.2125],
#         [0.8625, 0.9   , 0.35  ]],
#
#        [[1.    , 0.625 , 0.1375],
#         [0.925 , 0.8375, 0.2875],
#         [0.975 , 0.725 , 0.2   ]],
#
#        [[0.925 , 0.8375, 0.275 ],
#         [1.    , 0.65  , 0.15  ],
#         [0.95  , 0.8   , 0.25  ]],
#
#        [[0.925 , 0.8375, 0.275 ],
#         [0.9875, 0.6875, 0.175 ],
#         [0.875 , 0.8875, 0.3375]],
#
#        [[0.9875, 0.7   , 0.1875],
#         [0.9875, 0.7125, 0.1875],
#         [0.9875, 0.725 , 0.2   ]],
#
#        [[0.8875, 0.875 , 0.3125],
#         [0.85  , 0.9125, 0.35  ],
#         [0.975 , 0.75  , 0.2125]],
#
#        [[1.    , 0.65  , 0.1625],
#         [0.9625, 0.7625, 0.225 ],
#         [0.8375, 0.925 , 0.375 ]],
#
#        [[0.9625, 0.775 , 0.225 ],
#         [0.95  , 0.7875, 0.2375],
#         [0.95  , 0.8   , 0.25  ]],
#
#        [[0.8625, 0.9   , 0.35  ],
#         [0.9   , 0.8625, 0.3125],
#         [0.9   , 0.8625, 0.3125]],
#
#        [[0.95  , 0.8   , 0.25  ],
#         [0.9625, 0.775 , 0.225 ],
#         [0.9375, 0.825 , 0.2625]],
#
#        [[0.95  , 0.7875, 0.2375],
#         [0.9375, 0.8125, 0.2625],
#         [0.9875, 0.675 , 0.175 ]],
#
#        [[1.    , 0.65  , 0.15  ],
#         [0.9875, 0.6875, 0.175 ],
#         [0.8625, 0.9   , 0.35  ]],
#
#        [[0.975 , 0.725 , 0.2   ],
#         [0.975 , 0.725 , 0.2   ],
#         [1.    , 0.6375, 0.15  ]],
#
#        [[0.975 , 0.725 , 0.2   ],
#         [1.    , 0.6625, 0.1625],
#         [0.975 , 0.7375, 0.2125]],
#
#        [[0.975 , 0.7375, 0.2125],
#         [0.9875, 0.6875, 0.175 ],
#         [0.9875, 0.7   , 0.175 ]],
#
#        [[0.875 , 0.8875, 0.325 ],
#         [0.9625, 0.7625, 0.225 ],
#         [0.875 , 0.8875, 0.3375]],
#
#        [[0.9   , 0.875 , 0.3125],
#         [0.9375, 0.8   , 0.25  ],
#         [0.8375, 0.925 , 0.375 ]],
#
#        [[1.    , 0.6625, 0.1625],
#         [0.9625, 0.7625, 0.2125],
#         [0.9   , 0.8625, 0.3125]],
#
#        [[0.85  , 0.9125, 0.3625],
#         [0.975 , 0.7375, 0.2125],
#         [1.    , 0.6125, 0.1375]],
#
#        [[0.875 , 0.8875, 0.3375],
#         [0.925 , 0.825 , 0.275 ],
#         [0.9875, 0.725 , 0.2   ]],
#
#        [[0.9625, 0.775 , 0.225 ],
#         [0.95  , 0.7875, 0.2375],
#         [0.975 , 0.75  , 0.2125]],
#
#        [[0.9625, 0.775 , 0.225 ],
#         [0.8875, 0.875 , 0.3125],
#         [1.    , 0.65  , 0.1625]],
#
#        [[0.85  , 0.9125, 0.3625],
#         [0.85  , 0.9125, 0.3625],
#         [1.    , 0.6375, 0.15  ]],
#
#        [[0.9625, 0.7625, 0.225 ],
#         [0.875 , 0.8875, 0.3375],
#         [0.9125, 0.85  , 0.2875]],
#
#        [[0.95  , 0.7875, 0.2375],
#         [0.875 , 0.8875, 0.3375],
#         [1.    , 0.625 , 0.1375]],
#
#        [[0.9875, 0.7125, 0.1875],
#         [0.8875, 0.875 , 0.3125],
#         [0.95  , 0.7875, 0.2375]],
#
#        [[0.875 , 0.8875, 0.3375],
#         [0.9875, 0.7   , 0.1875],
#         [1.    , 0.625 , 0.15  ]],
#
#        [[0.9625, 0.7625, 0.225 ],
#         [0.9375, 0.8125, 0.2625],
#         [0.9875, 0.7125, 0.1875]],
#
#        [[0.9875, 0.6875, 0.175 ],
#         [0.975 , 0.7375, 0.2   ],
#         [0.8875, 0.875 , 0.3125]],
#
#        [[1.    , 0.6125, 0.1375],
#         [0.9625, 0.7625, 0.225 ],
#         [0.8625, 0.9   , 0.35  ]],
#
#        [[1.    , 0.65  , 0.1625],
#         [1.    , 0.625 , 0.15  ],
#         [0.975 , 0.7375, 0.2   ]],
#
#        [[0.9875, 0.675 , 0.175 ],
#         [0.925 , 0.825 , 0.275 ],
#         [0.95  , 0.7875, 0.2375]],
#
#        [[1.    , 0.6125, 0.1375],
#         [0.95  , 0.7875, 0.2375],
#         [0.85  , 0.9125, 0.3625]],
#
#        [[0.9375, 0.8125, 0.2625],
#         [0.9625, 0.775 , 0.2375],
#         [0.925 , 0.825 , 0.275 ]],
#
#        [[0.875 , 0.8875, 0.3375],
#         [0.8375, 0.9125, 0.3625],
#         [0.9   , 0.8625, 0.3   ]],
#
#        [[0.925 , 0.8375, 0.2875],
#         [0.9625, 0.775 , 0.225 ],
#         [0.875 , 0.8875, 0.3375]],
#
#        [[0.9875, 0.6875, 0.175 ],
#         [0.9625, 0.7625, 0.225 ],
#         [0.975 , 0.75  , 0.2125]],
#
#        [[1.    , 0.6125, 0.1375],
#         [0.9875, 0.7   , 0.1875],
#         [0.85  , 0.9125, 0.35  ]],
#
#        [[0.95  , 0.8   , 0.25  ],
#         [0.9   , 0.8625, 0.3   ],
#         [0.9125, 0.85  , 0.2875]],
#
#        [[1.    , 0.6625, 0.1625],
#         [1.    , 0.65  , 0.15  ],
#         [1.    , 0.6125, 0.1375]],
#
#        [[1.    , 0.675 , 0.1625],
#         [0.9875, 0.725 , 0.2   ],
#         [1.    , 0.6375, 0.15  ]],
#
#        [[1.    , 0.6375, 0.15  ],
#         [0.975 , 0.7375, 0.2125],
#         [1.    , 0.65  , 0.15  ]],
#
#        [[0.975 , 0.7375, 0.2   ],
#         [0.975 , 0.7375, 0.2   ],
#         [1.    , 0.6625, 0.1625]],
#
#        [[0.9875, 0.6875, 0.175 ],
#         [0.8875, 0.875 , 0.325 ],
#         [1.    , 0.65  , 0.15  ]],
#
#        [[0.95  , 0.8   , 0.25  ],
#         [0.9875, 0.6875, 0.175 ],
#         [0.9875, 0.7125, 0.1875]],
#
#        [[0.95  , 0.7875, 0.2375],
#         [0.9875, 0.6875, 0.175 ],
#         [0.85  , 0.9125, 0.3625]],
#
#        [[0.9875, 0.7   , 0.1875],
#         [0.9125, 0.85  , 0.3   ],
#         [0.85  , 0.9125, 0.3625]],
#
#        [[0.9875, 0.675 , 0.175 ],
#         [1.    , 0.6625, 0.1625],
#         [1.    , 0.675 , 0.1625]],
#
#        [[1.    , 0.65  , 0.15  ],
#         [0.925 , 0.8375, 0.2875],
#         [0.925 , 0.8375, 0.275 ]],
#
#        [[0.925 , 0.825 , 0.275 ],
#         [0.9875, 0.675 , 0.175 ],
#         [0.95  , 0.7875, 0.2375]],
#
#        [[0.9125, 0.85  , 0.2875],
#         [1.    , 0.625 , 0.15  ],
#         [0.9375, 0.8125, 0.25  ]],
#
#        [[0.8375, 0.9125, 0.3625],
#         [0.875 , 0.9   , 0.3375],
#         [0.975 , 0.75  , 0.2125]],
#
#        [[0.875 , 0.8875, 0.325 ],
#         [0.9375, 0.825 , 0.2625],
#         [1.    , 0.6625, 0.1625]],
#
#        [[0.9875, 0.7   , 0.175 ],
#         [0.9625, 0.7625, 0.225 ],
#         [0.95  , 0.8   , 0.25  ]],
#
#        [[0.9875, 0.7125, 0.1875],
#         [0.9125, 0.85  , 0.2875],
#         [0.95  , 0.7875, 0.2375]],
#
#        [[0.95  , 0.8   , 0.25  ],
#         [0.9875, 0.7   , 0.1875],
#         [1.    , 0.625 , 0.1375]],
#
#        [[0.925 , 0.825 , 0.275 ],
#         [0.95  , 0.8   , 0.25  ],
#         [0.975 , 0.75  , 0.2125]],
#
#        [[1.    , 0.625 , 0.15  ],
#         [1.    , 0.6375, 0.15  ],
#         [1.    , 0.6375, 0.15  ]],
#
#        [[0.975 , 0.7375, 0.2   ],
#         [1.    , 0.6375, 0.15  ],
#         [0.8625, 0.9   , 0.35  ]],
#
#        [[0.9875, 0.6875, 0.175 ],
#         [0.9875, 0.7125, 0.1875],
#         [0.9375, 0.8125, 0.2625]],
#
#        [[1.    , 0.65  , 0.15  ],
#         [1.    , 0.625 , 0.1375],
#         [0.9   , 0.8625, 0.3   ]],
#
#        [[0.975 , 0.7375, 0.2125],
#         [0.8625, 0.9   , 0.3375],
#         [1.    , 0.65  , 0.15  ]],
#
#        [[1.    , 0.6625, 0.1625],
#         [0.9875, 0.6875, 0.175 ],
#         [0.9625, 0.775 , 0.225 ]],
#
#        [[1.    , 0.6375, 0.15  ],
#         [1.    , 0.6375, 0.15  ],
#         [0.95  , 0.7875, 0.2375]],
#
#        [[0.9375, 0.825 , 0.2625],
#         [0.8625, 0.9   , 0.3375],
#         [1.    , 0.6625, 0.1625]],
#
#        [[1.    , 0.6375, 0.15  ],
#         [0.9125, 0.85  , 0.2875],
#         [0.975 , 0.7375, 0.2125]],
#
#        [[1.    , 0.65  , 0.15  ],
#         [0.9375, 0.8125, 0.25  ],
#         [0.9375, 0.8125, 0.2625]],
#
#        [[0.925 , 0.8375, 0.275 ],
#         [0.95  , 0.8   , 0.25  ],
#         [0.9625, 0.7625, 0.225 ]],
#
#        [[0.8375, 0.9125, 0.3625],
#         [0.9875, 0.7   , 0.1875],
#         [1.    , 0.6375, 0.15  ]],
#
#        [[0.8375, 0.925 , 0.375 ],
#         [0.9625, 0.775 , 0.225 ],
#         [0.8625, 0.9   , 0.35  ]],
#
#        [[0.95  , 0.8   , 0.25  ],
#         [0.8625, 0.9   , 0.35  ],
#         [1.    , 0.625 , 0.15  ]],
#
#        [[0.9125, 0.85  , 0.2875],
#         [0.975 , 0.75  , 0.2125],
#         [0.975 , 0.75  , 0.2125]],
#
#        [[0.8875, 0.8875, 0.325 ],
#         [1.    , 0.625 , 0.1375],
#         [1.    , 0.65  , 0.15  ]]])

# %%
x21=V1_fuzz[:,0]
y21=V1_fuzz[:,1]
z21=V1_fuzz[:,2]

x22=V2_fuzz[:,0]
y22=V2_fuzz[:,1]
z22=V2_fuzz[:,2]

x23=V3_fuzz[:,0]
y23=V3_fuzz[:,1]
z23=V3_fuzz[:,2]

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')

ax.scatter(x21, y21, z21, c='r', s=10, label='vector 1') 
ax.scatter(x22, y22, z22, c='g', s=10, label='vector 2') 
ax.scatter(x23, y23, z23, c='b', s=10, label='vector 3') 

ax.legend()
plt.title('Plot after quantization')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
V1_fuzzlist = V1_fuzz.tolist()
V2_fuzzlist = V2_fuzz.tolist()
V3_fuzzlist = V3_fuzz.tolist()

# %%
V1_fuzz.shape
# Out:
# (100, 3, 3)

# %%
max_v1=max(V1_fuzzlist, key=V1_fuzzlist.count)
max_v2=max(V2_fuzzlist, key=V2_fuzzlist.count)
max_v3=max(V3_fuzzlist, key=V3_fuzzlist.count)

#max_v1=np.asarray(max_v1)
print(max_v1,max_v2,max_v3)
# Out:
# [[1.0, 0.65, 0.1625], [0.9875, 0.6875, 0.175], [1.0, 0.675, 0.1625]] [[0.5375, 0.9875, 0.675], [0.5, 0.9875, 0.7125], [1.0, 0.675, 0.1625]] [[0.2625, 0.825, 0.9375], [0.2, 0.725, 0.9875], [0.175, 0.6875, 0.1625]]

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('low membership-->>')
ax.set_ylabel('medium membership-->>')
ax.set_zlabel('high membership-->>')

ax.scatter(x11, y11, z11, c='r', s=10, label='vector 1')
ax.scatter(x12, y12, z12, c='g', s=10, label='vector 2')
ax.scatter(x13, y13, z13, c='b', s=10, label='vector 3')

#ax.axis(xmin=0, xmax=10)
#ax.axis(ymin=0, ymax=10)
#ax.axis(zmin=0, zmax=10)
#unit vector
#ax.scatter(max_v1[0], max_v1[1], max_v1[2], c='r', s=50, label='vector 1', edgecolors='none') 
#ax.scatter(max_v2[0], max_v2[1], max_v2[2], c='g', s=50, label='vector 2', edgecolors='none') 
#ax.scatter(max_v3[0], max_v3[1], max_v3[2], c='b', s=50, label='vector 3', edgecolors='none')



ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')



max_v1_mag=np.sqrt(max_v1[0]**2 + max_v1[1]**2 + max_v1[2]**2)
max_v1_xdirect = (max_v1[0]/max_v1_mag)
max_v1_ydirect = (max_v1[1]/max_v1_mag)
max_v1_zdirect = (max_v1[2]/max_v1_mag)


max_v2_mag=np.sqrt(max_v2[0]**2 + max_v2[1]**2 + max_v2[2]**2)
max_v2_xdirect = (max_v2[0]/max_v2_mag)
max_v2_ydirect = (max_v2[1]/max_v2_mag)
max_v2_zdirect = (max_v2[2]/max_v2_mag)


max_v3_mag=np.sqrt(max_v3[0]**2 + max_v3[1]**2 + max_v3[2]**2)
max_v3_xdirect = (max_v3[0]/max_v3_mag)
max_v3_ydirect = (max_v3[1]/max_v3_mag)
max_v3_zdirect = (max_v3[2]/max_v3_mag)


ax.quiver(0, 0, 0, max_v1_xdirect, max_v1_ydirect, max_v1_zdirect, length = 0.9, normalize = True, color='r')
ax.quiver(0, 0, 0, max_v2_xdirect, max_v2_ydirect, max_v2_zdirect, length = 0.9,normalize = True, color='g')
ax.quiver(0, 0, 0, max_v3_xdirect, max_v3_ydirect, max_v3_zdirect, length = 0.4, normalize = True, color='b')

plt.title('Plot with direction vector')
ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')

ax.scatter(x1, y1, z1, c='r', s=10) 
ax.scatter(x2, y2, z2, c='g', s=10) 
ax.scatter(x3, y3, z3, c='b', s=10) 



#unit vector
ax.scatter(max_v1[0], max_v1[1], max_v1[2], c='r', s=50, label='vector 1') 
ax.scatter(max_v2[0], max_v2[1], max_v2[2], c='g', s=50, label='vector 2') 
ax.scatter(max_v3[0], max_v3[1], max_v3[2], c='b', s=50, label='vector 3')



ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')



max_v1_mag=np.sqrt(max_v1[0]**2 + max_v1[1]**2 + max_v1[2]**2)
max_v1_xdirect = (max_v1[0]/max_v1_mag)
max_v1_ydirect = (max_v1[1]/max_v1_mag)
max_v1_zdirect = (max_v1[2]/max_v1_mag)


max_v2_mag=np.sqrt(max_v2[0]**2 + max_v2[1]**2 + max_v2[2]**2)
max_v2_xdirect = (max_v2[0]/max_v2_mag)
max_v2_ydirect = (max_v2[1]/max_v2_mag)
max_v2_zdirect = (max_v2[2]/max_v2_mag)


max_v3_mag=np.sqrt(max_v3[0]**2 + max_v3[1]**2 + max_v3[2]**2)
max_v3_xdirect = (max_v3[0]/max_v3_mag)
max_v3_ydirect = (max_v3[1]/max_v3_mag)
max_v3_zdirect = (max_v3[2]/max_v3_mag)


ax.quiver(0, 0, 0, max_v1_xdirect, max_v1_ydirect, max_v1_zdirect, length = 80, normalize = True, color='r')
ax.quiver(0, 0, 0, max_v2_xdirect, max_v2_ydirect, max_v2_zdirect, length = 80, normalize = True, color='g')
ax.quiver(0, 0, 0, max_v3_xdirect, max_v3_ydirect, max_v3_zdirect, length = 80, normalize = True, color='b')

ax.axis(xmin=0, xmax=100)
ax.axis(ymin=0, ymax=100)
ax.axis(zmin=0, zmax=100)

ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
xnew=70;
ynew=70;
znew=70;

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')

ax.scatter(x1, y1, z1, c='r', s=10) 
ax.scatter(x2, y2, z2, c='g', s=10) 
ax.scatter(x3, y3, z3, c='b', s=10) 
ax.scatter(xnew, ynew, znew, c='k', s=10) 


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [raw]
# mag_new=np.sqrt(xnew**2+ynew**2+znew**2)

# %%
V_new=[xnew,ynew,znew]
V_new=np.asarray(V_new)

# %%
s_new = fuzz.membership.gaussmf(V_new, 0, 50)
m_new = fuzz.membership.gaussmf(V_new, 50, 50)
l_new = fuzz.membership.gaussmf(V_new, 100, 50)
s_new
# Out:
# array([0.3753111, 0.3753111, 0.3753111])

# %%
V_new_fuzzified=[s_new,m_new,l_new]
V_new_fuzzified
# Out:
# [array([0.3753111, 0.3753111, 0.3753111]),
#  array([0.92311635, 0.92311635, 0.92311635]),
#  array([0.83527021, 0.83527021, 0.83527021])]

# %%
V_new_fuzz = uniform_midtread_quantizer(V_new_fuzzified, step_size)
V_new_fuzz
# Out:
# array([[0.375 , 0.375 , 0.375 ],
#        [0.925 , 0.925 , 0.925 ],
#        [0.8375, 0.8375, 0.8375]])

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('low membership-->>')
ax.set_ylabel('medium membership-->>')
ax.set_zlabel('high membership-->>')

ax.scatter(x11, y11, z11, c='r', s=10) 
ax.scatter(x12, y12, z12, c='g', s=10) 
ax.scatter(x13, y13, z13, c='b', s=10) 
ax.scatter(V_new_fuzzified[0], V_new_fuzzified[1], V_new_fuzzified[2], c='k', s=10) 

#ax.axis(xmin=0, xmax=10)
#ax.axis(ymin=0, ymax=10)
#ax.axis(zmin=0, zmax=10)
plt.title('Plot after fuzzification with new point')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [raw]
# inds_new = np.digitize(V_new_fuzzified, bins)
# V_new_fuzz = inds_new/10
# V_new_fuzz

# %%
# %matplotlib notebook

plt.rcParams['figure.figsize']=(6,6)
plt.rcParams['figure.dpi']=100

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')

ax.scatter(x21, y21, z21, c='r', s=10, label='vector 1', edgecolors='none') 
ax.scatter(x22, y22, z22, c='g', s=10, label='vector 2', edgecolors='none') 
ax.scatter(x23, y23, z23, c='b', s=10, label='vector 3', edgecolors='none') 
ax.scatter(V_new_fuzz[0], V_new_fuzz[1], V_new_fuzz[2], c='k', s=10, label='new vector', edgecolors='none') 

ax.legend()
plt.title('Plot after quantization with new point')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
dist1 = np.linalg.norm(V_new_fuzz - max_v1)
dist2 = np.linalg.norm(V_new_fuzz - max_v2)
dist3 = np.linalg.norm(V_new_fuzz - max_v3)

# %%
print(dist1,dist2,dist3)
# Out:
# 1.6435004563431068 0.338193731461717 0.4946589734352346

# %%
for i in range(100):
    for j in range(3):
        if (0<V1_fuzz[i][j]<=0.1):
            V1_fuzz[i][j]=0;
        elif (0.1<V1_fuzz[i][j]<=0.3):
            V1_fuzz[i][j]=0.2;
        elif (0.3<V1_fuzz[i][j]<=0.5):
            V1_fuzz[i][j]=0.4;
        elif (0.5<V1_fuzz[i][j]<=0.7):
            V1_fuzz[i][j]=0.6;
        elif (0.7<V1_fuzz[i][j]<=0.9):
            V1_fuzz[i][j]=0.8;
        elif (0.9<V1_fuzz[i][j]<=1):
            V1_fuzz[i][j]=1;

# %%
V1_fuzz
# Out:
# array([[0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.4, 1. , 0.8],
#        [0.4, 0.8, 0.8],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.4, 1. , 0.8],
#        [0.4, 1. , 0.8],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.4, 1. , 0.8],
#        [0.2, 0.6, 1. ],
#        [0.4, 0.8, 0.8],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0. , 0.4, 1. ],
#        [0.4, 1. , 0.8],
#        [0.4, 1. , 0.8],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.4, 1. , 0.8],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.4, 1. , 0.8],
#        [0.2, 0.8, 1. ],
#        [0.4, 1. , 0.8],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.6, 1. , 0.8],
#        [0.4, 1. , 0.8],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.4, 1. , 0.8],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.4, 1. , 0.8],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.4, 1. , 0.8],
#        [0.4, 0.8, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.4, 0.8, 0.8],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.4, 1. , 0.8],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.4, 1. , 0.8],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.4, 0.8, 0.8],
#        [0.4, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.4, 1. , 0.8],
#        [0.2, 0.6, 1. ],
#        [0.4, 1. , 0.8],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.4, 1. , 0.8],
#        [0.4, 1. , 0.8],
#        [0.4, 0.8, 0.8],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.4, 1. , 0.8],
#        [0.4, 1. , 0.8],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ]])

# %%
for i in range(100):
    for j in range(3):
        if (0<V2_fuzz[i][j]<=0.1):
            V2_fuzz[i][j]=0;
        elif (0.1<V2_fuzz[i][j]<=0.3):
            V2_fuzz[i][j]=0.2;
        elif (0.3<V2_fuzz[i][j]<=0.5):
            V2_fuzz[i][j]=0.4;
        elif (0.5<V2_fuzz[i][j]<=0.7):
            V2_fuzz[i][j]=0.6;
        elif (0.7<V2_fuzz[i][j]<=0.9):
            V2_fuzz[i][j]=0.8;
        elif (0.9<V2_fuzz[i][j]<=1):
            V2_fuzz[i][j]=1;

# %%
V2_fuzz
# Out:
# array([[0.2, 0.6, 1. ],
#        [0. , 0.4, 0.8],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 0.8],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.8, 1. ],
#        [0. , 0.2, 0.8],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 0.8],
#        [0. , 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 0.8],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 0.8],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 0.8],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.8, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.8, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ]])

# %%
for i in range(100):
    for j in range(3):
        if (0<V3_fuzz[i][j]<=0.1):
            V3_fuzz[i][j]=0;
        elif (0.1<V3_fuzz[i][j]<=0.3):
            V3_fuzz[i][j]=0.2;
        elif (0.3<V3_fuzz[i][j]<=0.5):
            V3_fuzz[i][j]=0.4;
        elif (0.5<V3_fuzz[i][j]<=0.7):
            V3_fuzz[i][j]=0.6;
        elif (0.7<V3_fuzz[i][j]<=0.9):
            V3_fuzz[i][j]=0.8;
        elif (0.9<V3_fuzz[i][j]<=1):
            V3_fuzz[i][j]=1;

# %%
V3_fuzz
# Out:
# array([[0. , 0.2, 0.8],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.2, 0.8],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 0.8],
#        [0. , 0.2, 0.8],
#        [0.2, 0.6, 1. ],
#        [0. , 0.2, 0.8],
#        [0. , 0.4, 0.8],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.2, 0.6],
#        [0.2, 0.8, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 0.8],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 0.8],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.2, 0.8],
#        [0. , 0.2, 0.8],
#        [0. , 0.2, 0.8],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.2, 0.8],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 0.8],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.2, 0.8],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 0.8],
#        [0.2, 0.8, 1. ],
#        [0. , 0.2, 0.8],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 0.8],
#        [0. , 0.4, 1. ],
#        [0.2, 0.8, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 0.8],
#        [0. , 0.4, 1. ],
#        [0. , 0.2, 0.8],
#        [0. , 0.4, 0.8],
#        [0. , 0.4, 1. ],
#        [0. , 0.4, 1. ],
#        [0. , 0.2, 0.8],
#        [0.2, 0.6, 1. ],
#        [0. , 0.2, 0.8],
#        [0. , 0.2, 0.8],
#        [0.2, 0.6, 1. ],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ],
#        [0.2, 0.6, 1. ],
#        [0. , 0.2, 0.8],
#        [0. , 0.4, 1. ],
#        [0. , 0.2, 0.8],
#        [0. , 0.4, 1. ],
#        [0.2, 0.6, 1. ]])

# %%
for i in range(100):
    for j in range(3):
        if (0<V1_fu[i][0][j]<=0.1):
            V1_fu[i][0][j]=0;
        elif (0.1<V1_fu[i][0][j]<=0.3):
            V1_fu[i][0][j]=0.2;
        elif (0.3<V1_fu[i][0][j]<=0.5):
            V1_fu[i][0][j]=0.4;
        elif (0.5<V1_fu[i][0][j]<=0.7):
            V1_fu[i][0][j]=0.6;
        elif (0.7<V1_fu[i][0][j]<=0.9):
            V1_fu[i][0][j]=0.8;
        elif (0.9<V1_fu[i][0][j]<=1):
            V1_fu[i][0][j]=1;

# %%
V1_fu
# Out:
# array([[[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]],
#
#        [[0.2, 0.8, 1. ]]])
